# %%
import os
from ultralytics import YOLO
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display

model = YOLO("../models/v3.pt")

def detect_objects(directory, conf=0.25):
    predictions = {}

    for filename in os.listdir(directory):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            img_path = os.path.join(directory, filename)
            results = model(img_path, imgsz=640, conf=conf)
            img_with_boxes = results[0].plot()

            plt.figure(figsize=(12, 6))
            plt.imshow(img_with_boxes)
            plt.axis("off")
            plt.title(f"Detecciones: {filename}")
            display(plt.gcf())
            plt.close()

    return predictions

# %%
DIRECTORY = '../dataset/detect/'

detect_objects(DIRECTORY)
# Out:
# image 1/1 c:\Users\Artur\Desktop\TEC\8vo\TC3002B\M2-ML\Cattle-Segmentation\source\..\dataset\detect\2025-04-04-07-58-03.jpg: 384x640 1 cow, 46.0ms
# Speed: 2.0ms preprocess, 46.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 c:\Users\Artur\Desktop\TEC\8vo\TC3002B\M2-ML\Cattle-Segmentation\source\..\dataset\detect\2025-04-04-10-02-03.jpg: 384x640 1 cow, 16.0ms
# Speed: 2.0ms preprocess, 16.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 c:\Users\Artur\Desktop\TEC\8vo\TC3002B\M2-ML\Cattle-Segmentation\source\..\dataset\detect\2025-04-04-10-24-03.jpg: 384x640 1 cow, 14.0ms
# Speed: 2.0ms preprocess, 14.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 c:\Users\Artur\Desktop\TEC\8vo\TC3002B\M2-ML\Cattle-Segmentation\source\..\dataset\detect\2025-04-04-11-39-03.jpg: 384x640 1 cow, 13.0ms
# Speed: 2.0ms preprocess, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# {}
